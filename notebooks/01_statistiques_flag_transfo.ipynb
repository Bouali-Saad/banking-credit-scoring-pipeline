# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2
from sqlalchemy import create_engine


plt.rcParams['figure.figsize'] = (12, 6)
sns.set_style('whitegrid')

engine = create_engine('postgresql://postgres:Saad2002@localhost:5433/pfe_credit_dw')
print('Connexion réussie !')
# Out:
# Connexion réussie !

# %%
df = pd.read_sql("""
    SELECT COUNT(*) AS nb_lignes,
           COUNT(DISTINCT TIERS_CLIENT) AS nb_clients
    FROM raw.flag_transfo
""", engine)
print(df)
# Out:
#    nb_lignes  nb_clients
# 0    8570101      693995

# %%
sns.histplot(df["age_client"], bins=30)
plt.title("Distribution Age Client")
plt.show()
